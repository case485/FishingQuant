# %% [markdown]
# <a href="https://colab.research.google.com/github/case485/FishingQuant/blob/main/LakeInfo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install python-weather
# !pip -q install googlemaps
# !pip -q install dash

# %%
import bs4
import requests
import requests, json 
import pandas as pd
import googlemaps
from datetime import datetime
import locale
import re
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objects as go
import pickle
from os import path

# %%
# !cp drive/MyDrive/mySecrets.py .
import mySecrets

#API Keys
googleApiKey = mySecrets.lakeSecrets['googleApiKey']
home = mySecrets.lakeSecrets['home']
weatherApiKey = mySecrets.lakeSecrets['weatherApiKey']

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# Out:
# 'en_US.UTF-8'

# %%
def getLakeList(url):
  response = requests.get(url)
  df = pd.DataFrame(columns =['Lake Name'])
  baseLakeUrl = "https://tpwd.texas.gov/fishboat/fish/recreational/lakes/"
  soup = bs4.BeautifulSoup(response.content)
  lakeList = soup.find("div", {"class": "list2col"})
  lakeList = lakeList.find_all(href=True)
  print(lakeList)
  targetLakeList = []
  lakeRefName =[]
  for lake in lakeList: 
    lakeRefName.append(lake['href'])
    targetLakeList.append(baseLakeUrl + lake['href'])
  df["URL"] = targetLakeList
  df['Lake Name Orig'] =     lakeRefName
  df['Reference Name'] = df['Lake Name Orig'].str.replace('_','-')
  df["Lake Name"] = [s + " Lake" for s in lakeRefName]
  return(df)

# %%
def getRatings(lake):
  try:
    response = requests.get(lake)
    soup = bs4.BeautifulSoup(response.content)
    ratings = soup.find("table", {"id": "Ratings"})
    trList = ratings.find_all("tr")
    tdList = trList[1].find_all("td")
    largemouth = '<td><img alt="yes" class="nomargin" src="../images/icons/largemouth.gif"/></td>' 
    formalLakeName = soup.select('h1')[0].text.strip()
  except: 
    return("Not Found", "Not Found")
  try :
    tdList.index("yes")
  except:
    pass
  i=0
 
  for td in tdList:
    x = td.find("img")
    if(x):
      if i == 0:
        ranking = "Poor"
      elif i ==1:
        ranking = "Fair"
      elif i ==2:
        ranking = "Good"
      elif i == 3:
        ranking = "Excelent"
      else:
        ranking = "Not Found"
    i = i +1
  return(ranking,formalLakeName )

# %%
def getLakeArea(url):
  area =0
  try:
    response = requests.get(url)
    soup = bs4.BeautifulSoup(response.content)
    area = soup.find(text=re.compile(".*Surface acres:.* |.*Surface area:.*"  ))
    area = area.split()[2]
  except:
    area = 0
  if type(area) is str:
    area = locale.atof(area)
    return(area)
  return(area)

# %%
def getWaterLevel(lake):
  lake = lake.replace("_", "-")
  url = "https://waterdatafortexas.org/reservoirs/individual/" + lake
  response = requests.get(url)
  soup = bs4.BeautifulSoup(response.content)
  waterLevel = soup.find("small")
  if(type(waterLevel) is bs4.element.Tag ):
    waterLevel = waterLevel.get_text()
    waterLevel = waterLevel.split(" ")
    waterLevel = waterLevel[1]
  return(waterLevel)

# %%
def getWaterTempature(lake):
  url = "https://www.lakemonster.com/lake/TX/" + lake 
  response = requests.get(url)
  soup = bs4.BeautifulSoup(response.content)
  waterTemp = soup.find(id = "water_text")
  if(type(waterTemp) is bs4.element.Tag ):
    waterTemp = waterTemp.get_text()
    waterTemp = waterTemp.split(" ")
    waterTemp = waterTemp[0]
  return(waterTemp)

# %%
def getCityNamefromLake(lake):
  lake = lake + ", Tx"
  lake = lake.replace("/","")
  lake = lake.replace("-"," ")
  locationDict = {"zipCode" : None,
                  "lat" : None,
                  "lng" : None, 
                  "lakeName" : None
                  }
  gmaps = googlemaps.Client(key=googleApiKey)
  try: 
    geocode_result = gmaps.geocode(lake)
    try:
      locationDict["zipCode"] = geocode_result[0]["address_components"][4]["long_name"]
    except: 
      locationDict["zipCode"] = "11111"
    lat = geocode_result[0]["geometry"]["bounds"]["northeast"]["lat"]
    locationDict["lng"] = geocode_result[0]["geometry"]["bounds"]["northeast"]["lng"]
    locationDict["lakeName"] = lake
    try:
      locationDict["Location"] = geocode_result[0]["formatted_address"]
    except:
      locationDict["Location"] = "N/A"
  except: 
    print("Error")
    return("N/A", "N/A", "N/A", "N/A")
  return(locationDict["Location"], locationDict["zipCode"], lat, locationDict["lng"])

# %%
def getDistanceFromHome(location):
  distance = "None"
  gmaps = googlemaps.Client(key=googleApiKey)
  location = location + " Tx"
  try:
    distanceTemp = gmaps.distance_matrix(home, location,units = "imperial")
    distance = distanceTemp["rows"][0]['elements'][0]["distance"]["text"]
    distance = distance.split()[0]
  except:
    distance = "0"
  return(float(distance))

# %%
def getShareALunkerLakes():
  url = "https://texassharelunker.com/mobifish/services/sharelunker/query/sl_query.aspx?op=downloadCSV"
  df = pd.read_csv(url)
  df.reset_index(inplace=True)
  df = df.rename(columns=df.iloc[0]).drop(df.index[0])
  lakesSeries = df['lake_name'].value_counts()
  return(lakesSeries)

# %%
def addLunkers(lake, lunkerLakesSeries):
  lake = lake.replace("/", "")
  lake = lake.replace("_", " ")
  lake = lake.replace("-", " ")
  lake = lake.title()
  substring = lake.strip()
  strings_with_substring = [string for string in lunkerLakesSeries.keys().to_list() if substring in string]
  try:
    lunkers = lunkerLakesSeries[strings_with_substring][0]
  except:
    lunkers = 0
  return(lunkers)

# %%
def getWeather(city_name="Waco"):
  print("****************************************************")
  print(f"Orig City : {city_name}")
  city_name = city_name.replace('Lake','')
  if(city_name == "N/A"):
    return(0, 0)
  current_temperature = 0 
  current_pressure= 0
  try:
    print(f"Adj City :{city_name}")
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    complete_url = base_url + "appid=" + weatherApiKey + "&q=" + city_name 
    print(complete_url)
  except:
    print("Error on City Name Resolution")
    return(0, 0)
  try:
    x = requests.get(complete_url) 
    x = x.json()
    print(x["main"])
    y = x["main"] 
    current_temperature = int(1.8*(int(y["temp"]) - 273) + 32)
    print(type(current_temperature))
    fTemp = 1.8*(current_temperature - 273) + 32
    current_pressure = y["pressure"] 
    current_humidiy = y["humidity"] 
    z = x["weather"] 
    weather_description = z[0]["description"] 
    print(" Temperature (F) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidiy) +
          "\n description = " +
                    str(weather_description)) 
  except: 
    print("Error")
  return(current_temperature, current_pressure)

# %%
def getRegionalList():
  filePath = f"/content/drive/MyDrive/Colab Notebooks/lakeData.pkl"
  if (path.exists(filePath)):
    print(f"File already exists, reading in pickle")
    dfLake = pd.read_pickle(filePath)
  else: 
    dfLake = pd.DataFrame(columns =['Lake Name'])
    urlList = ["https://tpwd.texas.gov/fishboat/fish/recreational/lakes/inplains.phtml", "https://tpwd.texas.gov/fishboat/fish/recreational/lakes/ineast.phtml", "https://tpwd.texas.gov/fishboat/fish/recreational/lakes/inhillco.phtml","https://tpwd.texas.gov/fishboat/fish/recreational/lakes/inpanhd.phtml"]
    print(f"URLList: {urlList}")
    for url in urlList:
      dfLake = pd.concat([dfLake, getLakeList(url)])
    dfLake.to_pickle(filePath)
  return(dfLake)

# %%
def getBassRecord(url):
  baseUrl = "https://tpwd.texas.gov/fishboat/fish/action/waterecords.php?"
  try: 
    response = requests.get(url)
    soup = bs4.BeautifulSoup(response.content)
    for link in soup.findAll('a', href=True, text="Lake Records"):
      wbCode = link['href'].split("?")[1]
    recordUrl = baseUrl + wbCode
    df_list = pd.read_html(recordUrl)
    rodRecords = df_list[0]
    bassRecord = rodRecords.loc[rodRecords['Species'] == 'Bass, Largemouth']
    bassRecord = bassRecord['Weight'].values[0]
  except:
    bassRecord = 0
  return(float(bassRecord))

# %%
def buildDataframe(dfLake):
  filePath = f"/content/drive/MyDrive/Colab Notebooks/lakeInfo.pkl"
  if (path.exists(filePath)):
    dfLake = pd.read_pickle(filePath)
  else: 
    dfLake[['Ratings','Formal Lake Name']] = dfLake.apply(lambda row: pd.Series(getRatings(row["URL"])), axis=1)
    dfLake['Area'] = dfLake.apply(lambda row: getLakeArea(row["URL"]), axis = 1) 
    dfLake['Water Level'] = dfLake.apply(lambda row: getWaterLevel(row["Reference Name"]), axis = 1) 
    dfLake['Water Temp'] = dfLake.apply(lambda row: getWaterTempature(row["Reference Name"]), axis = 1) 
    dfLake[['Location', "Zip Code", "Lat", "Lng"]] = dfLake.apply(lambda row: pd.Series(getCityNamefromLake(row["Reference Name"])), axis = 1) 
    dfLake['Distance'] = dfLake.apply(lambda row: getDistanceFromHome(row["Location"]), axis = 1) 
    lunkerLakesSeries = getShareALunkerLakes()
    dfLake['Lunkers'] = dfLake.apply(lambda row: addLunkers(row["Reference Name"], lunkerLakesSeries), axis = 1) 
    dfLake["Lunkers per Acre"] = round( dfLake['Lunkers']/ dfLake["Area"] , 4)
    dfLake[["Air Temperature", "Atmospheric Pressure"]] = dfLake.apply(lambda row: pd.Series(getWeather(row["Location"])), axis = 1)
    dfLake["Bass Record"] =  dfLake.apply(lambda row: getBassRecord(row["URL"]), axis = 1) 
    dfLake.to_pickle(filePath)
  return(dfLake)

# %%
dfLake = getRegionalList()
# dfLake = dfLake.iloc[:3]
# Out:
# URLList: ['https://tpwd.texas.gov/fishboat/fish/recreational/lakes/inplains.phtml', 'https://tpwd.texas.gov/fishboat/fish/recreational/lakes/ineast.phtml', 'https://tpwd.texas.gov/fishboat/fish/recreational/lakes/inhillco.phtml', 'https://tpwd.texas.gov/fishboat/fish/recreational/lakes/inpanhd.phtml']
# [<a href="alvarado">Alvarado Park</a>, <a href="amon_carter">Amon G. Carter</a>, <a href="aquilla">Aquilla</a>, <a href="arlington">Arlington</a>, <a href="athens">Athens</a>, <a href="bachman">Bachman</a>, <a href="bardwell">Bardwell</a>, <a href="bastrop">Bastrop</a>, <a href="belton">Belton</a>, <a href="benbrook">Benbrook</a>, <a href="big_creek">Big Creek</a>, <a href="bonham">Bonham City</a>, <a href="bonhamsp">Bonham State Park</a>, <a href="brazos">Brazos</a>, <a href="bridgeport">Bridgeport</a>, <a href="bryan">Bryan</a>, <a href="cedar_creek">Cedar Creek</a>, <a href="cleburnesp">Cleburne State Park</a>, <a href="coffee_mill">Coffee Mill</a>, <a href="cooper">Cooper</a>, <a href="crook">Crook</a>, <a href="cypress_springs">Cypress Springs</a>, <a href="davy_crockett">Davy Crockett</a>, <a href="eagle_mountain">Eagle Mountain</a>, <a href="fairfield">Fairfield</a>, <a href="fayette">Fayette County</a>, <a href="fort_parker">Fort Parker State Park</a>, <a href="gibbons_creek">Gibbons Creek</a>, <a href="gonzales">Gonzales</a>, <a href="granbury">Granbury</a>, <a href="grapevine">Grapevine</a>, <a href="halbert">Halbert</a>, <a href="joe_pool">Joe Pool</a>, <a href="lavon">Lavon</a>, <a href="lewisville">Lewisville</a>, <a href="limestone">Limestone</a>, <a href="meridiansp">Meridian State Park</a>, <a href="marine_creek">Marine Creek</a>, <a href="mexia">Mexia</a>, <a href="mill_creek">Mill Creek</a>, <a href="mineral_wells">Mineral Wells</a>, <a href="moss">Moss</a>, <a href="mountain_creek">Mountain Creek</a>, <a href="muenster">Muenster</a>, <a href="navarro">Navarro Mills</a>, <a href="nocona">Nocona</a>, <a href="palestine">Palestine</a>, <a href="pat_cleburne">Pat Cleburne</a>, <a href="pat_mayse">Pat Mayse</a>, <a href="proctor">Proctor</a>, <a href="purtis_creek">Purtis Creek State Park </a>, <a href="ray_hubbard">Ray Hubbard</a>, <a href="ray_roberts">Ray Roberts</a>, <a href="richland_chambers">Richland Chambers</a>, <a href="somerville">Somerville</a>, <a href="squaw_creek/">Squaw Creek</a>, <a href="stillhouse_hollow">Stillhouse Hollow</a>, <a href="sulphur_springs">Sulphur Springs</a>, <a href="tawakoni">Tawakoni</a>, <a href="texoma">Texoma</a>, <a href="tradinghouse">Tradinghouse Creek</a>, <a href="waco">Waco</a>, <a href="waxahachie">Waxahachie</a>, <a href="weatherford">Weatherford</a>, <a href="wheeler_branch">Wheeler Branch</a>, <a href="white_rock">White Rock</a>, <a href="whitney">Whitney</a>, <a href="wood">Wood</a>, <a href="worth">Worth</a>]
# [<a href="steinhagen">B.A. Steinhagen</a>, <a href="bob_sandlin">Bob Sandlin</a>, <a href="brandy_branch">Brandy Branch</a>, <a href="caddo">Caddo</a>, <a href="conroe">Conroe</a>, <a href="fork">Fork</a>, <a href="gilmer">Gilmer</a>, <a href="gladewater">Gladewater City</a>, <a href="hawkins">Hawkins</a>, <a href="holbrook">Holbrook</a>, <a href="houston_county">Houston County</a>, <a href="jacksonville">Jacksonville</a>, <a href="kurth">Kurth</a>, <a href="lop">Lake O' the Pines</a>, <a href="livingston">Livingston</a>, <a href="lone_star">Lone Star</a>, <a href="martin_creek">Martin Creek</a>, <a href="monticello">Monticello</a>, <a href="murvaul">Murvaul</a>, <a href="nacogdoches">Nacogdoches</a>, <a href="naconiche">Naconiche</a>, <a href="pinkston">Pinkston</a>, <a href="quitman">Quitman</a>, <a href="raven">Raven</a>, <a href="sam_rayburn">Sam Rayburn</a>, <a href="striker">Striker</a>, <a href="timpson">Timpson</a>, <a href="toledo_bend">Toledo Bend</a>, <a href="tyler">Tyler</a>, <a href="welsh">Welsh</a>, <a href="winnsboro">Winnsboro</a>, <a href="wright_patman">Wright Patman</a>]
# [<a href="austin/">Austin</a>, <a href="brady_creek/">Brady Creek</a>, <a href="brownwood/">Brownwood</a>, <a href="buchanan/">Buchanan</a>, <a href="canyon/">Canyon</a>, <a href="georgetown/">Georgetown</a>, <a href="granger/">Granger</a>, <a href="inks/">Inks</a>, <a href="lbj/">LBJ</a>, <a href="marble_falls/">Marble Falls</a>, <a href="medina/">Medina</a>, <a href="lady_bird/">Lady Bird</a>, <a href="travis/">Travis</a>, <a href="walter_long/">Walter E. Long</a>]
# [<a href="abilene">Abilene</a>, <a href="alan_henry">Alan Henry</a>, <a href="arrowhead">Arrowhead</a>, <a href="baylor">Baylor Creek/Childress</a>, <a href="bryson">Bryson</a>, <a href="buffalo_creek">Buffalo Creek</a>, <a href="buffalo_springs">Buffalo Springs</a>, <a href="champion_creek">Champion Creek</a>, <a href="cisco">Cisco</a>, <a href="clyde">Clyde</a>, <a href="coleman">Coleman</a>, <a href="colorado_city">Colorado City</a>, <a href="daniel">Daniel</a>, <a href="diversion">Diversion</a>, <a href="spence">E.V. Spence</a>, <a href="fort_phantom">Fort Phantom Hill</a>, <a href="fryer">Fryer</a>, <a href="graham">Graham</a>, <a href="greenbelt">Greenbelt</a>, <a href="hords_creek">Hords Creek</a>, <a href="hubbard_creek">Hubbard Creek</a>, <a href="jacksboro">Jacksboro</a>, <a href="j_b_thomas">J.B. Thomas</a>, <a href="kemp">Kemp</a>, <a href="kickapoo">Kickapoo</a>, <a href="kirby">Kirby</a>, <a href="leon">Leon</a>, <a href="lost_creek">Lost Creek</a>, <a href="mackenzie">Mackenzie</a>, <a href="mcclellan">McClellan</a>, <a href="meredith">Meredith</a>, <a href="millers">Millers Creek</a>, <a href="nasworthy">Nasworthy</a>, <a href="new_ballinger">New Ballinger</a>, <a href="o_c_fisher">O.C. Fisher</a>, <a href="o_h_ivie">O.H. Ivie</a>, <a href="oak_creek">Oak Creek</a>, <a href="palo_duro">Palo Duro</a>, <a href="palo_pinto">Palo Pinto</a>, <a href="possum_kingdom">Possum Kingdom</a>, <a href="proctor">Proctor</a>, <a href="stamford">Stamford</a>, <a href="sweetwater">Sweetwater</a>, <a href="twin_buttes">Twin Buttes</a>, <a href="white_river">White River</a>, <a href="winters_elmcreek/">Winters-Elm Creek</a>, <a href="wichita">Wichita</a>]

# %%
dfLake = buildDataframe(dfLake)
# Out:
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# ****************************************************
# Orig City : Alvarado, TX 76009, USA
# Adj City :Alvarado, TX 76009, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Alvarado, TX 76009, USA
# {'temp': 298.96, 'feels_like': 299.55, 'temp_min': 298.96, 'temp_max': 298.96, 'pressure': 1013, 'humidity': 75, 'sea_level': 1013, 'grnd_level': 967}
# <class 'int'>
#  Temperature (F) = 77
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 75
#  description = few clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Aquilla, TX 76622, USA
# Adj City :Aquilla, TX 76622, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Aquilla, TX 76622, USA
# {'temp': 285.15, 'feels_like': 283.71, 'temp_min': 285.15, 'temp_max': 285.15, 'pressure': 1028, 'humidity': 50}
# <class 'int'>
#  Temperature (F) = 53
#  atmospheric pressure (in hPa unit) = 1028
#  humidity (in percentage) = 50
#  description = few clouds
# ****************************************************
# Orig City : Arlington, TX, USA
# Adj City :Arlington, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Arlington, TX, USA
# {'temp': 294.45, 'feels_like': 294.93, 'temp_min': 293.2, 'temp_max': 295.33, 'pressure': 1016, 'humidity': 88}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 88
#  description = broken clouds
# ****************************************************
# Orig City : Athens, TX, USA
# Adj City :Athens, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Athens, TX, USA
# {'temp': 294.98, 'feels_like': 294.08, 'temp_min': 293.15, 'temp_max': 296.48, 'pressure': 1015, 'humidity': 33}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 33
#  description = few clouds
# ****************************************************
# Orig City : Bachman Lake, Dallas, TX, USA
# Adj City :Bachman , Dallas, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Bachman , Dallas, TX, USA
# Error
# ****************************************************
# Orig City : Bardwell, TX, USA
# Adj City :Bardwell, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Bardwell, TX, USA
# {'temp': 284.66, 'feels_like': 284.11, 'temp_min': 284.26, 'temp_max': 284.82, 'pressure': 992, 'humidity': 86}
# <class 'int'>
#  Temperature (F) = 51
#  atmospheric pressure (in hPa unit) = 992
#  humidity (in percentage) = 86
#  description = moderate rain
# ****************************************************
# Orig City : Bastrop, TX 78602, USA
# Adj City :Bastrop, TX 78602, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Bastrop, TX 78602, USA
# {'temp': 295.17, 'feels_like': 295.52, 'temp_min': 294.59, 'temp_max': 295.35, 'pressure': 1022, 'humidity': 80}
# <class 'int'>
#  Temperature (F) = 71
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 80
#  description = clear sky
# ****************************************************
# Orig City : Belton, TX, USA
# Adj City :Belton, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Belton, TX, USA
# {'temp': 294.26, 'feels_like': 294.88, 'temp_min': 293.51, 'temp_max': 295.27, 'pressure': 1015, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 94
#  description = overcast clouds
# ****************************************************
# Orig City : Benbrook, TX, USA
# Adj City :Benbrook, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Benbrook, TX, USA
# {'temp': 294.47, 'feels_like': 294.96, 'temp_min': 293.71, 'temp_max': 295.15, 'pressure': 1017, 'humidity': 88}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 88
#  description = broken clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Bonham, TX 75418, USA
# Adj City :Bonham, TX 75418, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Bonham, TX 75418, USA
# {'temp': 293.78, 'feels_like': 294.35, 'temp_min': 293.1, 'temp_max': 294.47, 'pressure': 1019, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 94
#  description = overcast clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Brazos County, TX, USA
# Adj City :Brazos County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Brazos County, TX, USA
# Error
# ****************************************************
# Orig City : Bridgeport, TX 76426, USA
# Adj City :Bridgeport, TX 76426, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Bridgeport, TX 76426, USA
# {'temp': 289.13, 'feels_like': 289, 'temp_min': 287.01, 'temp_max': 292.56, 'pressure': 1033, 'humidity': 85}
# <class 'int'>
#  Temperature (F) = 60
#  atmospheric pressure (in hPa unit) = 1033
#  humidity (in percentage) = 85
#  description = clear sky
# ****************************************************
# Orig City : Bryan, TX, USA
# Adj City :Bryan, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Bryan, TX, USA
# {'temp': 294.8, 'feels_like': 295.42, 'temp_min': 293.79, 'temp_max': 295.27, 'pressure': 1016, 'humidity': 92}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 92
#  description = overcast clouds
# ****************************************************
# Orig City : Cedar Creek, TX, USA
# Adj City :Cedar Creek, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Cedar Creek, TX, USA
# {'temp': 292.78, 'feels_like': 293.1, 'temp_min': 292.04, 'temp_max': 293.15, 'pressure': 1019, 'humidity': 88}
# <class 'int'>
#  Temperature (F) = 66
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 88
#  description = scattered clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Cooper, TX 75432, USA
# Adj City :Cooper, TX 75432, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Cooper, TX 75432, USA
# {'temp': 293.91, 'feels_like': 294.63, 'temp_min': 293.46, 'temp_max': 294.41, 'pressure': 1019, 'humidity': 99}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 99
#  description = overcast clouds
# ****************************************************
# Orig City : Lake Crook, Paris, TX 75460, USA
# Adj City : Crook, Paris, TX 75460, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Crook, Paris, TX 75460, USA
# Error
# ****************************************************
# Orig City : Lake Cypress Springs, Texas, USA
# Adj City : Cypress Springs, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Cypress Springs, Texas, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Fairfield, TX, USA
# Adj City :Fairfield, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Fairfield, TX, USA
# {'temp': 282.02, 'feels_like': 279.71, 'temp_min': 278.4, 'temp_max': 285.34, 'pressure': 1015, 'humidity': 35}
# <class 'int'>
#  Temperature (F) = 48
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 35
#  description = clear sky
# ****************************************************
# Orig City : Fayette County, TX, USA
# Adj City :Fayette County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Fayette County, TX, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Gibbons Creek Reservoir, Texas 77830, USA
# Adj City :Gibbons Creek Reservoir, Texas 77830, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Gibbons Creek Reservoir, Texas 77830, USA
# Error
# ****************************************************
# Orig City : Gonzales, TX 78629, USA
# Adj City :Gonzales, TX 78629, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Gonzales, TX 78629, USA
# {'temp': 281.22, 'feels_like': 280.05, 'temp_min': 277.99, 'temp_max': 284.29, 'pressure': 1016, 'humidity': 93, 'sea_level': 1016, 'grnd_level': 1011}
# <class 'int'>
#  Temperature (F) = 46
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 93
#  description = clear sky
# ****************************************************
# Orig City : Granbury, TX, USA
# Adj City :Granbury, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Granbury, TX, USA
# {'temp': 294.25, 'feels_like': 294.9, 'temp_min': 293.42, 'temp_max': 295.06, 'pressure': 1018, 'humidity': 95}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 95
#  description = broken clouds
# ****************************************************
# Orig City : Grapevine, TX, USA
# Adj City :Grapevine, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Grapevine, TX, USA
# {'temp': 281.06, 'feels_like': 280.2, 'temp_min': 277.4, 'temp_max': 284.54, 'pressure': 1015, 'humidity': 45, 'sea_level': 1015, 'grnd_level': 960}
# <class 'int'>
#  Temperature (F) = 46
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 45
#  description = clear sky
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Joe Pool Lake, Texas, USA
# Adj City :Joe Pool , Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Joe Pool , Texas, USA
# Error
# ****************************************************
# Orig City : Lavon, TX, USA
# Adj City :Lavon, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Lavon, TX, USA
# {'temp': 296.25, 'feels_like': 295.58, 'temp_min': 295.54, 'temp_max': 303.25, 'pressure': 1010, 'humidity': 37, 'sea_level': 1010, 'grnd_level': 947}
# <class 'int'>
#  Temperature (F) = 73
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 37
#  description = clear sky
# ****************************************************
# Orig City : Lewisville, TX, USA
# Adj City :Lewisville, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Lewisville, TX, USA
# {'temp': 294.7, 'feels_like': 295.08, 'temp_min': 294.26, 'temp_max': 295.15, 'pressure': 1017, 'humidity': 83}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 83
#  description = broken clouds
# ****************************************************
# Orig City : Limestone County, TX, USA
# Adj City :Limestone County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Limestone County, TX, USA
# Error
# ****************************************************
# Orig City : Meridian, TX 76665, USA
# Adj City :Meridian, TX 76665, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Meridian, TX 76665, USA
# {'temp': 280.23, 'feels_like': 276.62, 'temp_min': 278.71, 'temp_max': 281.15, 'pressure': 1010, 'humidity': 66}
# <class 'int'>
#  Temperature (F) = 44
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 66
#  description = clear sky
# ****************************************************
# Orig City : Marine Creek Pkwy, Texas, USA
# Adj City :Marine Creek Pkwy, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Marine Creek Pkwy, Texas, USA
# Error
# ****************************************************
# Orig City : Mexia, TX 76667, USA
# Adj City :Mexia, TX 76667, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Mexia, TX 76667, USA
# {'temp': 294.02, 'feels_like': 294.64, 'temp_min': 293.55, 'temp_max': 294.21, 'pressure': 1017, 'humidity': 95}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 95
#  description = overcast clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Mineral Wells, TX, USA
# Adj City :Mineral Wells, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Mineral Wells, TX, USA
# {'temp': 293.32, 'feels_like': 293.85, 'temp_min': 293.15, 'temp_max': 293.71, 'pressure': 1016, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 94
#  description = mist
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Mountain Creek, Dallas, TX, USA
# Adj City :Mountain Creek, Dallas, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Mountain Creek, Dallas, TX, USA
# {'temp': 289.46, 'feels_like': 289.42, 'temp_min': 286.77, 'temp_max': 289.97, 'pressure': 1018, 'humidity': 87}
# <class 'int'>
#  Temperature (F) = 60
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 87
#  description = overcast clouds
# ****************************************************
# Orig City : Muenster, TX 76252, USA
# Adj City :Muenster, TX 76252, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Muenster, TX 76252, USA
# {'temp': 270.78, 'feels_like': 265.67, 'temp_min': 270.78, 'temp_max': 270.78, 'pressure': 1026, 'humidity': 97, 'sea_level': 1026, 'grnd_level': 954}
# <class 'int'>
#  Temperature (F) = 26
#  atmospheric pressure (in hPa unit) = 1026
#  humidity (in percentage) = 97
#  description = snow
# ****************************************************
# Orig City : Navarro County, TX, USA
# Adj City :Navarro County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Navarro County, TX, USA
# Error
# ****************************************************
# Orig City : Nocona, TX 76255, USA
# Adj City :Nocona, TX 76255, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Nocona, TX 76255, USA
# {'temp': 293.34, 'feels_like': 294.03, 'temp_min': 293.15, 'temp_max': 293.71, 'pressure': 1018, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 100
#  description = overcast clouds
# ****************************************************
# Orig City : Palestine, TX, USA
# Adj City :Palestine, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Palestine, TX, USA
# {'temp': 294.2, 'feels_like': 294.97, 'temp_min': 294.15, 'temp_max': 294.26, 'pressure': 1018, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 100
#  description = broken clouds
# ****************************************************
# Orig City : Lake Pat Cleburne, Cleburne, TX 76033, USA
# Adj City : Pat Cleburne, Cleburne, TX 76033, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Pat Cleburne, Cleburne, TX 76033, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Purtis Creek, Texas 75124, USA
# Adj City :Purtis Creek, Texas 75124, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Purtis Creek, Texas 75124, USA
# Error
# ****************************************************
# Orig City : Lake Ray Hubbard, Dallas, TX, USA
# Adj City : Ray Hubbard, Dallas, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Ray Hubbard, Dallas, TX, USA
# Error
# ****************************************************
# Orig City : Lake Ray Roberts, Texas, USA
# Adj City : Ray Roberts, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Ray Roberts, Texas, USA
# Error
# ****************************************************
# Orig City : Richland-Chambers Reservoir, Texas, USA
# Adj City :Richland-Chambers Reservoir, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Richland-Chambers Reservoir, Texas, USA
# Error
# ****************************************************
# Orig City : Somerville, TX 77879, USA
# Adj City :Somerville, TX 77879, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Somerville, TX 77879, USA
# {'temp': 289.89, 'feels_like': 289.5, 'temp_min': 287.15, 'temp_max': 292.04, 'pressure': 1034, 'humidity': 72}
# <class 'int'>
#  Temperature (F) = 60
#  atmospheric pressure (in hPa unit) = 1034
#  humidity (in percentage) = 72
#  description = clear sky
# ****************************************************
# Orig City : Squaw Creek Reservoir, Texas, USA
# Adj City :Squaw Creek Reservoir, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Squaw Creek Reservoir, Texas, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Sulphur Springs, TX 75482, USA
# Adj City :Sulphur Springs, TX 75482, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Sulphur Springs, TX 75482, USA
# {'temp': 294, 'feels_like': 294.75, 'temp_min': 293.44, 'temp_max': 294.72, 'pressure': 1019, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 100
#  description = overcast clouds
# ****************************************************
# Orig City : West Tawakoni, TX 75474, USA
# Adj City :West Tawakoni, TX 75474, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=West Tawakoni, TX 75474, USA
# {'temp': 294.7, 'feels_like': 295.37, 'temp_min': 293.71, 'temp_max': 295.93, 'pressure': 1018, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 94
#  description = overcast clouds
# ****************************************************
# Orig City : Texoma, USA
# Adj City :Texoma, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Texoma, USA
# Error
# ****************************************************
# Orig City : Tradinghouse Creek Reservoir, Texas, USA
# Adj City :Tradinghouse Creek Reservoir, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Tradinghouse Creek Reservoir, Texas, USA
# Error
# ****************************************************
# Orig City : Waco, TX, USA
# Adj City :Waco, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Waco, TX, USA
# {'temp': 294.65, 'feels_like': 295.15, 'temp_min': 294.15, 'temp_max': 295.15, 'pressure': 1017, 'humidity': 88}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 88
#  description = broken clouds
# ****************************************************
# Orig City : Waxahachie, TX, USA
# Adj City :Waxahachie, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Waxahachie, TX, USA
# {'temp': 293.47, 'feels_like': 294.17, 'temp_min': 293.15, 'temp_max': 293.71, 'pressure': 1018, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 100
#  description = overcast clouds
# ****************************************************
# Orig City : Weatherford, TX, USA
# Adj City :Weatherford, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Weatherford, TX, USA
# {'temp': 294.05, 'feels_like': 294.68, 'temp_min': 293.71, 'temp_max': 294.26, 'pressure': 1017, 'humidity': 95}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 95
#  description = overcast clouds
# ****************************************************
# Orig City : Wheeler Branch Reservoir, Texas 76043, USA
# Adj City :Wheeler Branch Reservoir, Texas 76043, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Wheeler Branch Reservoir, Texas 76043, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Whitney, TX 76692, USA
# Adj City :Whitney, TX 76692, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Whitney, TX 76692, USA
# {'temp': 286.74, 'feels_like': 284.73, 'temp_min': 285.57, 'temp_max': 287.55, 'pressure': 1004, 'humidity': 22}
# <class 'int'>
#  Temperature (F) = 55
#  atmospheric pressure (in hPa unit) = 1004
#  humidity (in percentage) = 22
#  description = clear sky
# ****************************************************
# Orig City : Wood County, TX, USA
# Adj City :Wood County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Wood County, TX, USA
# Error
# ****************************************************
# Orig City : Fort Worth, TX, USA
# Adj City :Fort Worth, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Fort Worth, TX, USA
# {'temp': 294.64, 'feels_like': 295.27, 'temp_min': 293.4, 'temp_max': 295.31, 'pressure': 1017, 'humidity': 93}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 93
#  description = overcast clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Lake Bob Sandlin, Texas, USA
# Adj City : Bob Sandlin, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Bob Sandlin, Texas, USA
# Error
# ****************************************************
# Orig City : Brandy Branch, Texas, USA
# Adj City :Brandy Branch, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Brandy Branch, Texas, USA
# Error
# ****************************************************
# Orig City : Caddo, TX 76429, USA
# Adj City :Caddo, TX 76429, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Caddo, TX 76429, USA
# {'temp': 293.84, 'feels_like': 294.5, 'temp_min': 292.87, 'temp_max': 294.22, 'pressure': 1019, 'humidity': 97, 'sea_level': 1019, 'grnd_level': 993}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 97
#  description = overcast clouds
# ****************************************************
# Orig City : Conroe, TX, USA
# Adj City :Conroe, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Conroe, TX, USA
# {'temp': 294.99, 'feels_like': 295.68, 'temp_min': 294.82, 'temp_max': 295.37, 'pressure': 1016, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 94
#  description = overcast clouds
# ****************************************************
# Orig City : Lake Fork, Texas, USA
# Adj City : Fork, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Fork, Texas, USA
# Error
# ****************************************************
# Orig City : Gilmer, TX, USA
# Adj City :Gilmer, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Gilmer, TX, USA
# {'temp': 294.08, 'feels_like': 294.68, 'temp_min': 293.72, 'temp_max': 294.58, 'pressure': 1019, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 94
#  description = overcast clouds
# ****************************************************
# Orig City : Gladewater, TX 75647, USA
# Adj City :Gladewater, TX 75647, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Gladewater, TX 75647, USA
# {'temp': 294.1, 'feels_like': 294.81, 'temp_min': 293.7, 'temp_max': 294.56, 'pressure': 1019, 'humidity': 98, 'sea_level': 1019, 'grnd_level': 1005}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 98
#  description = overcast clouds
# ****************************************************
# Orig City : Hawkins, TX 75765, USA
# Adj City :Hawkins, TX 75765, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Hawkins, TX 75765, USA
# {'temp': 293.88, 'feels_like': 294.62, 'temp_min': 293.71, 'temp_max': 294.26, 'pressure': 1016, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 100
#  description = overcast clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Houston County, TX, USA
# Adj City :Houston County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Houston County, TX, USA
# Error
# ****************************************************
# Orig City : Jacksonville, TX 75766, USA
# Adj City :Jacksonville, TX 75766, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Jacksonville, TX 75766, USA
# {'temp': 296.78, 'feels_like': 297.31, 'temp_min': 294.17, 'temp_max': 298.18, 'pressure': 1026, 'humidity': 81}
# <class 'int'>
#  Temperature (F) = 73
#  atmospheric pressure (in hPa unit) = 1026
#  humidity (in percentage) = 81
#  description = scattered clouds
# ****************************************************
# Orig City : Kurth Lake, Texas 75901, USA
# Adj City :Kurth , Texas 75901, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Kurth , Texas 75901, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Livingston, TX 77351, USA
# Adj City :Livingston, TX 77351, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Livingston, TX 77351, USA
# {'temp': 292.67, 'feels_like': 292.58, 'temp_min': 292.15, 'temp_max': 293.15, 'pressure': 1026, 'humidity': 73}
# <class 'int'>
#  Temperature (F) = 66
#  atmospheric pressure (in hPa unit) = 1026
#  humidity (in percentage) = 73
#  description = clear sky
# ****************************************************
# Orig City : Lone Star, TX 75668, USA
# Adj City :Lone Star, TX 75668, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Lone Star, TX 75668, USA
# {'temp': 294.23, 'feels_like': 294.85, 'temp_min': 293.71, 'temp_max': 294.82, 'pressure': 1019, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 94
#  description = overcast clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Lake Murvaul, Texas, USA
# Adj City : Murvaul, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Murvaul, Texas, USA
# Error
# ****************************************************
# Orig City : Nacogdoches, TX, USA
# Adj City :Nacogdoches, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Nacogdoches, TX, USA
# {'temp': 294.22, 'feels_like': 294.99, 'temp_min': 294.15, 'temp_max': 294.26, 'pressure': 1018, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 100
#  description = mist
# ****************************************************
# Orig City : Lake Naconiche, Texas, USA
# Adj City : Naconiche, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Naconiche, Texas, USA
# Error
# ****************************************************
# Orig City : Pinkston Reservoir, Texas 75935, USA
# Adj City :Pinkston Reservoir, Texas 75935, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Pinkston Reservoir, Texas 75935, USA
# Error
# ****************************************************
# Orig City : Quitman, TX 75783, USA
# Adj City :Quitman, TX 75783, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Quitman, TX 75783, USA
# {'temp': 294.05, 'feels_like': 294.65, 'temp_min': 293.69, 'temp_max': 295.39, 'pressure': 1018, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 94
#  description = overcast clouds
# ****************************************************
# Orig City : Lake Raven, Texas 77358, USA
# Adj City : Raven, Texas 77358, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Raven, Texas 77358, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Lake Striker, Texas, USA
# Adj City : Striker, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Striker, Texas, USA
# Error
# ****************************************************
# Orig City : Timpson, TX 75975, USA
# Adj City :Timpson, TX 75975, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Timpson, TX 75975, USA
# {'temp': 294.36, 'feels_like': 295.12, 'temp_min': 293.87, 'temp_max': 294.97, 'pressure': 1019, 'humidity': 99, 'sea_level': 1019, 'grnd_level': 1005}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 99
#  description = overcast clouds
# ****************************************************
# Orig City : Toledo Bend Reservoir, United States
# Adj City :Toledo Bend Reservoir, United States
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Toledo Bend Reservoir, United States
# Error
# ****************************************************
# Orig City : Tyler, TX, USA
# Adj City :Tyler, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Tyler, TX, USA
# {'temp': 294.06, 'feels_like': 293.85, 'temp_min': 293.4, 'temp_max': 294.22, 'pressure': 1017, 'humidity': 63}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 63
#  description = overcast clouds
# ****************************************************
# Orig City : Welsh Reservoir, Texas, USA
# Adj City :Welsh Reservoir, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Welsh Reservoir, Texas, USA
# Error
# ****************************************************
# Orig City : Winnsboro, TX 75494, USA
# Adj City :Winnsboro, TX 75494, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Winnsboro, TX 75494, USA
# {'temp': 293.74, 'feels_like': 293.63, 'temp_min': 292.15, 'temp_max': 294.82, 'pressure': 1031, 'humidity': 68}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1031
#  humidity (in percentage) = 68
#  description = clear sky
# ****************************************************
# Orig City : Wright Patman Lake, Texas, USA
# Adj City :Wright Patman , Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Wright Patman , Texas, USA
# Error
# ****************************************************
# Orig City : Austin, TX, USA
# Adj City :Austin, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Austin, TX, USA
# {'temp': 293.42, 'feels_like': 293.8, 'temp_min': 292.15, 'temp_max': 294.26, 'pressure': 1016, 'humidity': 88}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 88
#  description = mist
# ****************************************************
# Orig City : Brady Creek, Texas 76825, USA
# Adj City :Brady Creek, Texas 76825, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Brady Creek, Texas 76825, USA
# Error
# ****************************************************
# Orig City : Brownwood, TX, USA
# Adj City :Brownwood, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Brownwood, TX, USA
# {'temp': 292.45, 'feels_like': 292.73, 'temp_min': 292.04, 'temp_max': 293.15, 'pressure': 1017, 'humidity': 88}
# <class 'int'>
#  Temperature (F) = 66
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 88
#  description = clear sky
# ****************************************************
# Orig City : Buchanan Lake, Texas, USA
# Adj City :Buchanan , Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Buchanan , Texas, USA
# Error
# ****************************************************
# Orig City : Canyon, TX 79015, USA
# Adj City :Canyon, TX 79015, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Canyon, TX 79015, USA
# {'temp': 288.94, 'feels_like': 289, 'temp_min': 288.71, 'temp_max': 289.26, 'pressure': 1016, 'humidity': 93}
# <class 'int'>
#  Temperature (F) = 59
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 93
#  description = clear sky
# ****************************************************
# Orig City : Georgetown, TX, USA
# Adj City :Georgetown, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Georgetown, TX, USA
# {'temp': 298.15, 'feels_like': 299.16, 'temp_min': 298.15, 'temp_max': 298.15, 'pressure': 1014, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 77
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 94
#  description = broken clouds
# ****************************************************
# Orig City : Granger, TX 76530, USA
# Adj City :Granger, TX 76530, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Granger, TX 76530, USA
# {'temp': 294.28, 'feels_like': 294.33, 'temp_min': 293.19, 'temp_max': 296.14, 'pressure': 1028, 'humidity': 72, 'sea_level': 1028, 'grnd_level': 1000}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1028
#  humidity (in percentage) = 72
#  description = clear sky
# ****************************************************
# Orig City : Inks Lake, Texas, USA
# Adj City :Inks , Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Inks , Texas, USA
# Error
# ****************************************************
# Orig City : Lake Lyndon B. Johnson, Texas, USA
# Adj City : Lyndon B. Johnson, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Lyndon B. Johnson, Texas, USA
# Error
# ****************************************************
# Orig City : Marble Falls, TX 78654, USA
# Adj City :Marble Falls, TX 78654, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Marble Falls, TX 78654, USA
# {'temp': 291.53, 'feels_like': 292.03, 'temp_min': 290.93, 'temp_max': 292.15, 'pressure': 1017, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 64
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 100
#  description = clear sky
# ****************************************************
# Orig City : Medina, TX 78055, USA
# Adj City :Medina, TX 78055, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Medina, TX 78055, USA
# {'temp': 314.32, 'feels_like': 310.54, 'temp_min': 314.32, 'temp_max': 314.32, 'pressure': 1005, 'humidity': 6, 'sea_level': 1005, 'grnd_level': 941}
# <class 'int'>
#  Temperature (F) = 105
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 6
#  description = few clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Travis County, TX, USA
# Adj City :Travis County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Travis County, TX, USA
# Error
# ****************************************************
# Orig City : Lake Walter E. Long, Austin, TX, USA
# Adj City : Walter E. Long, Austin, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Walter E. Long, Austin, TX, USA
# Error
# ****************************************************
# Orig City : Abilene, TX, USA
# Adj City :Abilene, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Abilene, TX, USA
# {'temp': 291.44, 'feels_like': 291.78, 'temp_min': 290.93, 'temp_max': 292.59, 'pressure': 1016, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 64
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 94
#  description = clear sky
# ****************************************************
# Orig City : Lake Alan Henry, Texas, USA
# Adj City : Alan Henry, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Alan Henry, Texas, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Baylor County, TX, USA
# Adj City :Baylor County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Baylor County, TX, USA
# Error
# ****************************************************
# Orig City : Bryson, TX, USA
# Adj City :Bryson, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Bryson, TX, USA
# {'temp': 292.87, 'feels_like': 293.01, 'temp_min': 289.89, 'temp_max': 296.32, 'pressure': 1028, 'humidity': 81, 'sea_level': 1028, 'grnd_level': 1009}
# <class 'int'>
#  Temperature (F) = 66
#  atmospheric pressure (in hPa unit) = 1028
#  humidity (in percentage) = 81
#  description = overcast clouds
# ****************************************************
# Orig City : North Fork Buffalo Creek Reservoir, Texas 76360, USA
# Adj City :North Fork Buffalo Creek Reservoir, Texas 76360, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=North Fork Buffalo Creek Reservoir, Texas 76360, USA
# Error
# ****************************************************
# Orig City : Buffalo Springs, TX, USA
# Adj City :Buffalo Springs, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Buffalo Springs, TX, USA
# {'temp': 278.41, 'feels_like': 273.43, 'temp_min': 278.33, 'temp_max': 279.31, 'pressure': 1014, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 41
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 100
#  description = overcast clouds
# ****************************************************
# Orig City : Champion Creek, Texas 79512, USA
# Adj City :Champion Creek, Texas 79512, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Champion Creek, Texas 79512, USA
# Error
# ****************************************************
# Orig City : Cisco, TX 76437, USA
# Adj City :Cisco, TX 76437, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Cisco, TX 76437, USA
# {'temp': 291.83, 'feels_like': 292.26, 'temp_min': 291.24, 'temp_max': 293.41, 'pressure': 1017, 'humidity': 96}
# <class 'int'>
#  Temperature (F) = 64
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 96
#  description = overcast clouds
# ****************************************************
# Orig City : Clyde, TX 79510, USA
# Adj City :Clyde, TX 79510, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Clyde, TX 79510, USA
# {'temp': 278.56, 'feels_like': 277.46, 'temp_min': 278.56, 'temp_max': 278.56, 'pressure': 1023, 'humidity': 83, 'sea_level': 1023, 'grnd_level': 1002}
# <class 'int'>
#  Temperature (F) = 41
#  atmospheric pressure (in hPa unit) = 1023
#  humidity (in percentage) = 83
#  description = broken clouds
# ****************************************************
# Orig City : Coleman, TX 76834, USA
# Adj City :Coleman, TX 76834, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Coleman, TX 76834, USA
# {'temp': 272.08, 'feels_like': 270.11, 'temp_min': 270.93, 'temp_max': 274.15, 'pressure': 1026, 'humidity': 80}
# <class 'int'>
#  Temperature (F) = 30
#  atmospheric pressure (in hPa unit) = 1026
#  humidity (in percentage) = 80
#  description = overcast clouds
# ****************************************************
# Orig City : Colorado City, TX 79512, USA
# Adj City :Colorado City, TX 79512, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Colorado City, TX 79512, USA
# {'temp': 281.32, 'feels_like': 278.61, 'temp_min': 278.15, 'temp_max': 285.93, 'pressure': 1008, 'humidity': 45}
# <class 'int'>
#  Temperature (F) = 46
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 45
#  description = clear sky
# ****************************************************
# Orig City : Lake Daniel, Texas, USA
# Adj City : Daniel, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Daniel, Texas, USA
# Error
# ****************************************************
# Orig City : Lake Diversion, Texas, USA
# Adj City : Diversion, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Diversion, Texas, USA
# Error
# ****************************************************
# Orig City : E.V. Spence Reservoir, Texas 76945, USA
# Adj City :E.V. Spence Reservoir, Texas 76945, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=E.V. Spence Reservoir, Texas 76945, USA
# Error
# ****************************************************
# Orig City : Lake Fort Phantom Hill, Abilene, TX 79601, USA
# Adj City : Fort Phantom Hill, Abilene, TX 79601, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Fort Phantom Hill, Abilene, TX 79601, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Graham, TX 76450, USA
# Adj City :Graham, TX 76450, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Graham, TX 76450, USA
# {'temp': 293.42, 'feels_like': 293.85, 'temp_min': 292.9, 'temp_max': 294.53, 'pressure': 1010, 'humidity': 90}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 90
#  description = overcast clouds
# ****************************************************
# Orig City : Greenbelt Reservoir, Texas 79226, USA
# Adj City :Greenbelt Reservoir, Texas 79226, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Greenbelt Reservoir, Texas 79226, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Hubbard Creek, Texas 76430, USA
# Adj City :Hubbard Creek, Texas 76430, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Hubbard Creek, Texas 76430, USA
# {'temp': 293.9, 'feels_like': 293.83, 'temp_min': 293.44, 'temp_max': 294.97, 'pressure': 1025, 'humidity': 69, 'sea_level': 1025, 'grnd_level': 1016}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1025
#  humidity (in percentage) = 69
#  description = overcast clouds
# ****************************************************
# Orig City : Jacksboro, TX 76458, USA
# Adj City :Jacksboro, TX 76458, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Jacksboro, TX 76458, USA
# {'temp': 293.34, 'feels_like': 294.03, 'temp_min': 293.15, 'temp_max': 293.71, 'pressure': 1018, 'humidity': 100}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 100
#  description = broken clouds
# ****************************************************
# Orig City : Lake J B Thomas, Texas, USA
# Adj City : J B Thomas, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= J B Thomas, Texas, USA
# Error
# ****************************************************
# Orig City : Kemp, TX 75143, USA
# Adj City :Kemp, TX 75143, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Kemp, TX 75143, USA
# {'temp': 293.87, 'feels_like': 294.5, 'temp_min': 293.23, 'temp_max': 294.4, 'pressure': 1018, 'humidity': 96, 'sea_level': 1018, 'grnd_level': 996}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 96
#  description = overcast clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Kirby, TX, USA
# Adj City :Kirby, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Kirby, TX, USA
# {'temp': 292.15, 'feels_like': 292.56, 'temp_min': 290.37, 'temp_max': 293.15, 'pressure': 1016, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 66
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 94
#  description = few clouds
# ****************************************************
# Orig City : Leon County, TX, USA
# Adj City :Leon County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Leon County, TX, USA
# Error
# ****************************************************
# Orig City : Lost Creek, TX 78746, USA
# Adj City :Lost Creek, TX 78746, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Lost Creek, TX 78746, USA
# {'temp': 292.54, 'feels_like': 291.94, 'temp_min': 290.18, 'temp_max': 294.48, 'pressure': 1033, 'humidity': 54, 'sea_level': 1033, 'grnd_level': 992}
# <class 'int'>
#  Temperature (F) = 66
#  atmospheric pressure (in hPa unit) = 1033
#  humidity (in percentage) = 54
#  description = clear sky
# ****************************************************
# Orig City : Lake Mackenzie, Texas 79257, USA
# Adj City : Mackenzie, Texas 79257, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Mackenzie, Texas 79257, USA
# Error
# ****************************************************
# Orig City : McAllen, TX, USA
# Adj City :McAllen, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=McAllen, TX, USA
# {'temp': 296.28, 'feels_like': 296.95, 'temp_min': 295.93, 'temp_max': 297.04, 'pressure': 1014, 'humidity': 88}
# <class 'int'>
#  Temperature (F) = 73
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 88
#  description = broken clouds
# ****************************************************
# Orig City : Lake Meredith, Texas, USA
# Adj City : Meredith, Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Meredith, Texas, USA
# Error
# ****************************************************
# Orig City : Miller's Cove, TX, USA
# Adj City :Miller's Cove, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Miller's Cove, TX, USA
# Error
# ****************************************************
# Orig City : Lake Nasworthy, San Angelo, TX 76904, USA
# Adj City : Nasworthy, San Angelo, TX 76904, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q= Nasworthy, San Angelo, TX 76904, USA
# Error
# ****************************************************
# Orig City : New Ballinger Dr, Denton, TX 76226, USA
# Adj City :New Ballinger Dr, Denton, TX 76226, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=New Ballinger Dr, Denton, TX 76226, USA
# Error
# ****************************************************
# Orig City : O C Fisher Lake, Texas, USA
# Adj City :O C Fisher , Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=O C Fisher , Texas, USA
# Error
# ****************************************************
# Orig City : O.H. Ivie Lake, Texas, USA
# Adj City :O.H. Ivie , Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=O.H. Ivie , Texas, USA
# Error
# ****************************************************
# Orig City : Oak Creek, San Antonio, TX, USA
# Adj City :Oak Creek, San Antonio, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Oak Creek, San Antonio, TX, USA
# {'temp': 294.64, 'feels_like': 294.65, 'temp_min': 293.1, 'temp_max': 296.34, 'pressure': 1025, 'humidity': 69}
# <class 'int'>
#  Temperature (F) = 69
#  atmospheric pressure (in hPa unit) = 1025
#  humidity (in percentage) = 69
#  description = broken clouds
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Palo Pinto, TX 76484, USA
# Adj City :Palo Pinto, TX 76484, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Palo Pinto, TX 76484, USA
# {'temp': 293.03, 'feels_like': 293.58, 'temp_min': 292.64, 'temp_max': 293.27, 'pressure': 1023, 'humidity': 96, 'sea_level': 1023, 'grnd_level': 993}
# <class 'int'>
#  Temperature (F) = 68
#  atmospheric pressure (in hPa unit) = 1023
#  humidity (in percentage) = 96
#  description = light rain
# ****************************************************
# Orig City : Possum Kingdom Lake, Texas, USA
# Adj City :Possum Kingdom , Texas, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Possum Kingdom , Texas, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Stamford, TX, USA
# Adj City :Stamford, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Stamford, TX, USA
# {'temp': 290.12, 'feels_like': 290.04, 'temp_min': 287.03, 'temp_max': 292.72, 'pressure': 1033, 'humidity': 83}
# <class 'int'>
#  Temperature (F) = 62
#  atmospheric pressure (in hPa unit) = 1033
#  humidity (in percentage) = 83
#  description = scattered clouds
# ****************************************************
# Orig City : Sweetwater, TX 79556, USA
# Adj City :Sweetwater, TX 79556, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Sweetwater, TX 79556, USA
# {'temp': 292.37, 'feels_like': 292.8, 'temp_min': 292.15, 'temp_max': 292.59, 'pressure': 1017, 'humidity': 94}
# <class 'int'>
#  Temperature (F) = 66
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 94
#  description = overcast clouds
# ****************************************************
# Orig City : Twin Buttes Reservoir, Texas 76904, USA
# Adj City :Twin Buttes Reservoir, Texas 76904, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Twin Buttes Reservoir, Texas 76904, USA
# Error
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : N/A
# ****************************************************
# Orig City : Wichita County, TX, USA
# Adj City :Wichita County, TX, USA
# http://api.openweathermap.org/data/2.5/weather?appid=9cb2ed20a1779b1e65bb507659fccd16&q=Wichita County, TX, USA
# Error

# %%
dfLake
# Out:
#                  Lake Name  ... Bass Record
# 0            alvarado Lake  ...       12.77
# 1         amon_carter Lake  ...       14.44
# 2             aquilla Lake  ...       12.81
# 3           arlington Lake  ...       13.38
# 4              athens Lake  ...       14.19
# 5             bachman Lake  ...        7.80
# 6            bardwell Lake  ...       10.44
# 7             bastrop Lake  ...        9.98
# 8              belton Lake  ...       13.97
# 9            benbrook Lake  ...       13.66
# 10          big_creek Lake  ...       14.06
# 11             bonham Lake  ...       11.50
# 12           bonhamsp Lake  ...        0.00
# 13             brazos Lake  ...        8.55
# 14         bridgeport Lake  ...       12.73
# 15              bryan Lake  ...        7.73
# 16        cedar_creek Lake  ...       14.65
# 17         cleburnesp Lake  ...       11.58
# 18        coffee_mill Lake  ...        0.00
# 19             cooper Lake  ...       15.17
# 20              crook Lake  ...        0.00
# 21    cypress_springs Lake  ...       13.69
# 22      davy_crockett Lake  ...       12.59
# 23     eagle_mountain Lake  ...       11.65
# 24          fairfield Lake  ...       13.01
# 25            fayette Lake  ...       12.25
# 26        fort_parker Lake  ...        8.25
# 27      gibbons_creek Lake  ...       16.13
# 28           gonzales Lake  ...        0.00
# 29           granbury Lake  ...       11.89
# 30          grapevine Lake  ...       12.09
# 31            halbert Lake  ...        0.00
# 32           joe_pool Lake  ...       14.45
# 33              lavon Lake  ...       11.32
# 34         lewisville Lake  ...       13.63
# 35          limestone Lake  ...       11.75
# 36         meridiansp Lake  ...       12.17
# 37       marine_creek Lake  ...       14.57
# 38              mexia Lake  ...       10.12
# 39         mill_creek Lake  ...       16.77
# 40      mineral_wells Lake  ...       11.41
# 41               moss Lake  ...       13.25
# 42     mountain_creek Lake  ...        7.44
# 43           muenster Lake  ...        6.45
# 44            navarro Lake  ...       11.30
# 45             nocona Lake  ...       13.40
# 46          palestine Lake  ...       13.22
# 47       pat_cleburne Lake  ...       11.00
# 48          pat_mayse Lake  ...       14.10
# 49            proctor Lake  ...       13.96
# 50       purtis_creek Lake  ...       13.73
# 51        ray_hubbard Lake  ...       14.10
# 52        ray_roberts Lake  ...       15.18
# 53  richland_chambers Lake  ...       14.25
# 54         somerville Lake  ...       13.60
# 55       squaw_creek/ Lake  ...       11.17
# 56  stillhouse_hollow Lake  ...       13.00
# 57    sulphur_springs Lake  ...        1.90
# 58           tawakoni Lake  ...       14.00
# 59             texoma Lake  ...       11.90
# 60       tradinghouse Lake  ...       13.00
# 61               waco Lake  ...       13.87
# 62         waxahachie Lake  ...       12.31
# 63        weatherford Lake  ...       12.37
# 64     wheeler_branch Lake  ...       11.25
# 65         white_rock Lake  ...        8.41
# 66            whitney Lake  ...       11.63
# 67               wood Lake  ...        8.62
# 68              worth Lake  ...       12.00
# 0          steinhagen Lake  ...       12.00
# 1         bob_sandlin Lake  ...       14.31
# 2       brandy_branch Lake  ...       13.97
# 3               caddo Lake  ...       16.17
# 4              conroe Lake  ...       15.93
# 5                fork Lake  ...       18.18
# 6              gilmer Lake  ...       14.00
# 7          gladewater Lake  ...       13.60
# 8             hawkins Lake  ...       12.37
# 9            holbrook Lake  ...       13.13
# 10     houston_county Lake  ...       15.20
# 11       jacksonville Lake  ...       15.12
# 12              kurth Lake  ...        0.00
# 13                lop Lake  ...       15.13
# 14         livingston Lake  ...       13.19
# 15          lone_star Lake  ...       11.45
# 16       martin_creek Lake  ...       12.56
# 17         monticello Lake  ...       14.09
# 18            murvaul Lake  ...       14.87
# 19        nacogdoches Lake  ...       15.34
# 20          naconiche Lake  ...       14.12
# 21           pinkston Lake  ...       16.90
# 22            quitman Lake  ...       13.62
# 23              raven Lake  ...       13.48
# 24        sam_rayburn Lake  ...       16.80
# 25            striker Lake  ...       11.10
# 26            timpson Lake  ...        0.00
# 27        toledo_bend Lake  ...       15.32
# 28              tyler Lake  ...        0.00
# 29              welsh Lake  ...       15.23
# 30          winnsboro Lake  ...       10.75
# 31      wright_patman Lake  ...       12.28
# 0             austin/ Lake  ...       16.03
# 1        brady_creek/ Lake  ...       12.95
# 2          brownwood/ Lake  ...       13.58
# 3           buchanan/ Lake  ...       11.50
# 4             canyon/ Lake  ...       11.69
# 5         georgetown/ Lake  ...       10.60
# 6            granger/ Lake  ...       11.62
# 7               inks/ Lake  ...       12.50
# 8                lbj/ Lake  ...       13.70
# 9       marble_falls/ Lake  ...       11.18
# 10            medina/ Lake  ...       13.50
# 11         lady_bird/ Lake  ...       13.50
# 12            travis/ Lake  ...       14.21
# 13       walter_long/ Lake  ...       12.21
# 0             abilene Lake  ...       12.26
# 1          alan_henry Lake  ...       15.00
# 2           arrowhead Lake  ...       12.73
# 3              baylor Lake  ...       14.88
# 4              bryson Lake  ...       11.91
# 5       buffalo_creek Lake  ...        8.83
# 6     buffalo_springs Lake  ...       10.05
# 7      champion_creek Lake  ...       11.80
# 8               cisco Lake  ...       14.72
# 9               clyde Lake  ...       14.80
# 10            coleman Lake  ...       12.92
# 11      colorado_city Lake  ...       10.69
# 12             daniel Lake  ...       12.48
# 13          diversion Lake  ...        0.00
# 14             spence Lake  ...       14.20
# 15       fort_phantom Lake  ...       11.15
# 16              fryer Lake  ...        7.64
# 17             graham Lake  ...       12.34
# 18          greenbelt Lake  ...       12.34
# 19        hords_creek Lake  ...       12.96
# 20      hubbard_creek Lake  ...       12.93
# 21          jacksboro Lake  ...        7.80
# 22         j_b_thomas Lake  ...       10.02
# 23               kemp Lake  ...        8.63
# 24           kickapoo Lake  ...        5.64
# 25              kirby Lake  ...       10.88
# 26               leon Lake  ...       13.00
# 27         lost_creek Lake  ...        8.66
# 28          mackenzie Lake  ...       12.42
# 29          mcclellan Lake  ...        0.00
# 30           meredith Lake  ...       12.25
# 31            millers Lake  ...       11.19
# 32          nasworthy Lake  ...       12.71
# 33      new_ballinger Lake  ...       10.80
# 34         o_c_fisher Lake  ...       15.69
# 35           o_h_ivie Lake  ...       16.08
# 36          oak_creek Lake  ...       13.68
# 37          palo_duro Lake  ...        0.00
# 38         palo_pinto Lake  ...       11.12
# 39     possum_kingdom Lake  ...       16.02
# 40            proctor Lake  ...       13.96
# 41           stamford Lake  ...       12.48
# 42         sweetwater Lake  ...       13.41
# 43        twin_buttes Lake  ...       14.25
# 44        white_river Lake  ...       13.26
# 45  winters_elmcreek/ Lake  ...       12.13
# 46            wichita Lake  ...       10.25
#
# [162 rows x 19 columns]

# %%
dfLake.sort_values(by="Lunkers", ascending=False)
# Out:
#                  Lake Name  ... Bass Record
# 5                fork Lake  ...       18.18
# 4              conroe Lake  ...       15.93
# 24        sam_rayburn Lake  ...       16.80
# 4              athens Lake  ...       14.19
# 0             austin/ Lake  ...       16.03
# 1          alan_henry Lake  ...       15.00
# 6              gilmer Lake  ...       14.00
# 19        nacogdoches Lake  ...       15.34
# 11         lady_bird/ Lake  ...       13.50
# 4             canyon/ Lake  ...       11.69
# 13             brazos Lake  ...        8.55
# 46          palestine Lake  ...       13.22
# 56  stillhouse_hollow Lake  ...       13.00
# 9            benbrook Lake  ...       13.66
# 52        ray_roberts Lake  ...       15.18
# 32           joe_pool Lake  ...       14.45
# 51        ray_hubbard Lake  ...       14.10
# 50       purtis_creek Lake  ...       13.73
# 27        toledo_bend Lake  ...       15.32
# 20          naconiche Lake  ...       14.12
# 39         mill_creek Lake  ...       16.77
# 12            travis/ Lake  ...       14.21
# 39     possum_kingdom Lake  ...       16.02
# 3               caddo Lake  ...       16.17
# 66            whitney Lake  ...       11.63
# 68              worth Lake  ...       12.00
# 15       fort_phantom Lake  ...       11.15
# 37       marine_creek Lake  ...       14.57
# 36          oak_creek Lake  ...       13.68
# 18            murvaul Lake  ...       14.87
# 24          fairfield Lake  ...       13.01
# 14         bridgeport Lake  ...       12.73
# 54         somerville Lake  ...       13.60
# 10     houston_county Lake  ...       15.20
# 3           buchanan/ Lake  ...       11.50
# 3           arlington Lake  ...       13.38
# 64     wheeler_branch Lake  ...       11.25
# 33              lavon Lake  ...       11.32
# 23     eagle_mountain Lake  ...       11.65
# 1         bob_sandlin Lake  ...       14.31
# 43        twin_buttes Lake  ...       14.25
# 28              tyler Lake  ...        0.00
# 26               leon Lake  ...       13.00
# 10            coleman Lake  ...       12.92
# 34         lewisville Lake  ...       13.63
# 2          brownwood/ Lake  ...       13.58
# 21           pinkston Lake  ...       16.90
# 45             nocona Lake  ...       13.40
# 10            medina/ Lake  ...       13.50
# 20      hubbard_creek Lake  ...       12.93
# 61               waco Lake  ...       13.87
# 7               inks/ Lake  ...       12.50
# 63        weatherford Lake  ...       12.37
# 16        cedar_creek Lake  ...       14.65
# 14             spence Lake  ...       14.20
# 3              baylor Lake  ...       14.88
# 27      gibbons_creek Lake  ...       16.13
# 29           granbury Lake  ...       11.89
# 17         monticello Lake  ...       14.09
# 19        hords_creek Lake  ...       12.96
# 0            alvarado Lake  ...       12.77
# 60       tradinghouse Lake  ...       13.00
# 58           tawakoni Lake  ...       14.00
# 19             cooper Lake  ...       15.17
# 48          pat_mayse Lake  ...       14.10
# 1        brady_creek/ Lake  ...       12.95
# 8              belton Lake  ...       13.97
# 32          nasworthy Lake  ...       12.71
# 23              raven Lake  ...       13.48
# 16       martin_creek Lake  ...       12.56
# 11       jacksonville Lake  ...       15.12
# 9            holbrook Lake  ...       13.13
# 7          gladewater Lake  ...       13.60
# 22      davy_crockett Lake  ...       12.59
# 2       brandy_branch Lake  ...       13.97
# 59             texoma Lake  ...       11.90
# 28          mackenzie Lake  ...       12.42
# 2           arrowhead Lake  ...       12.73
# 25            fayette Lake  ...       12.25
# 42         sweetwater Lake  ...       13.41
# 41           stamford Lake  ...       12.48
# 30           meredith Lake  ...       12.25
# 44        white_river Lake  ...       13.26
# 8               cisco Lake  ...       14.72
# 22            quitman Lake  ...       13.62
# 9               clyde Lake  ...       14.80
# 25              kirby Lake  ...       10.88
# 18          greenbelt Lake  ...       12.34
# 38         palo_pinto Lake  ...       11.12
# 12              kurth Lake  ...        0.00
# 47       pat_cleburne Lake  ...       11.00
# 41               moss Lake  ...       13.25
# 14         livingston Lake  ...       13.19
# 2             aquilla Lake  ...       12.81
# 21    cypress_springs Lake  ...       13.69
# 10          big_creek Lake  ...       14.06
# 11             bonham Lake  ...       11.50
# 42     mountain_creek Lake  ...        7.44
# 26        fort_parker Lake  ...        8.25
# 24           kickapoo Lake  ...        5.64
# 23               kemp Lake  ...        8.63
# 22         j_b_thomas Lake  ...       10.02
# 15          lone_star Lake  ...       11.45
# 21          jacksboro Lake  ...        7.80
# 20              crook Lake  ...        0.00
# 30          grapevine Lake  ...       12.09
# 17             graham Lake  ...       12.34
# 16              fryer Lake  ...        7.64
# 31            halbert Lake  ...        0.00
# 28           gonzales Lake  ...        0.00
# 18        coffee_mill Lake  ...        0.00
# 27         lost_creek Lake  ...        8.66
# 12           bonhamsp Lake  ...        0.00
# 45  winters_elmcreek/ Lake  ...       12.13
# 5             bachman Lake  ...        7.80
# 6            bardwell Lake  ...       10.44
# 7             bastrop Lake  ...        9.98
# 40            proctor Lake  ...       13.96
# 37          palo_duro Lake  ...        0.00
# 35           o_h_ivie Lake  ...       16.08
# 13          diversion Lake  ...        0.00
# 34         o_c_fisher Lake  ...       15.69
# 33      new_ballinger Lake  ...       10.80
# 15              bryan Lake  ...        7.73
# 31            millers Lake  ...       11.19
# 17         cleburnesp Lake  ...       11.58
# 29          mcclellan Lake  ...        0.00
# 35          limestone Lake  ...       11.75
# 11      colorado_city Lake  ...       10.69
# 12             daniel Lake  ...       12.48
# 5         georgetown/ Lake  ...       10.60
# 13                lop Lake  ...       15.13
# 1         amon_carter Lake  ...       14.44
# 25            striker Lake  ...       11.10
# 26            timpson Lake  ...        0.00
# 8             hawkins Lake  ...       12.37
# 0          steinhagen Lake  ...       12.00
# 29              welsh Lake  ...       15.23
# 30          winnsboro Lake  ...       10.75
# 31      wright_patman Lake  ...       12.28
# 67               wood Lake  ...        8.62
# 65         white_rock Lake  ...        8.41
# 62         waxahachie Lake  ...       12.31
# 57    sulphur_springs Lake  ...        1.90
# 55       squaw_creek/ Lake  ...       11.17
# 6            granger/ Lake  ...       11.62
# 36         meridiansp Lake  ...       12.17
# 53  richland_chambers Lake  ...       14.25
# 8                lbj/ Lake  ...       13.70
# 9       marble_falls/ Lake  ...       11.18
# 49            proctor Lake  ...       13.96
# 44            navarro Lake  ...       11.30
# 13       walter_long/ Lake  ...       12.21
# 0             abilene Lake  ...       12.26
# 43           muenster Lake  ...        6.45
# 4              bryson Lake  ...       11.91
# 5       buffalo_creek Lake  ...        8.83
# 6     buffalo_springs Lake  ...       10.05
# 7      champion_creek Lake  ...       11.80
# 40      mineral_wells Lake  ...       11.41
# 38              mexia Lake  ...       10.12
# 46            wichita Lake  ...       10.25
#
# [162 rows x 19 columns]

# %%
dfLake.loc[dfLake['Ratings'] == "Excelent"]
# Out:
#               Lake Name  ... Bass Record
# 1      amon_carter Lake  ...       14.44
# 3        arlington Lake  ...       13.38
# 4           athens Lake  ...       14.19
# 7          bastrop Lake  ...        9.98
# 22   davy_crockett Lake  ...       12.59
# 25         fayette Lake  ...       12.25
# 27   gibbons_creek Lake  ...       16.13
# 30       grapevine Lake  ...       12.09
# 45          nocona Lake  ...       13.40
# 50    purtis_creek Lake  ...       13.73
# 52     ray_roberts Lake  ...       15.18
# 54      somerville Lake  ...       13.60
# 61            waco Lake  ...       13.87
# 64  wheeler_branch Lake  ...       11.25
# 65      white_rock Lake  ...        8.41
# 67            wood Lake  ...        8.62
# 3            caddo Lake  ...       16.17
# 4           conroe Lake  ...       15.93
# 5             fork Lake  ...       18.18
# 6           gilmer Lake  ...       14.00
# 9         holbrook Lake  ...       13.13
# 12           kurth Lake  ...        0.00
# 13             lop Lake  ...       15.13
# 17      monticello Lake  ...       14.09
# 19     nacogdoches Lake  ...       15.34
# 20       naconiche Lake  ...       14.12
# 21        pinkston Lake  ...       16.90
# 23           raven Lake  ...       13.48
# 24     sam_rayburn Lake  ...       16.80
# 26         timpson Lake  ...        0.00
# 27     toledo_bend Lake  ...       15.32
# 28           tyler Lake  ...        0.00
# 29           welsh Lake  ...       15.23
# 0          austin/ Lake  ...       16.03
# 11      lady_bird/ Lake  ...       13.50
# 13    walter_long/ Lake  ...       12.21
# 1       alan_henry Lake  ...       15.00
# 3           baylor Lake  ...       14.88
# 18       greenbelt Lake  ...       12.34
# 26            leon Lake  ...       13.00
# 44     white_river Lake  ...       13.26
#
# [41 rows x 19 columns]

# %%
df = dfLake
x = (pd.interval_range(start=dfLake['Lunkers per Acre'].min(), end= dfLake['Lunkers per Acre'].max(), periods=4))
x = x.to_tuples().to_list()
limits = [(0,2),(3,10),(11,20),(21,50),(50,3000)]
colors = ["royalblue","crimson","lightseagreen","orange","lightgrey"]
cities = []
scale = 5000
fig = go.Figure()
for i in range(len(limits)):
    lim = limits[i]
    df_sub = dfLake[lim[0]:lim[1]]
    fig.add_trace(go.Scattergeo(
        locationmode = 'USA-states',
        lon = dfLake['Lng'],
        lat = dfLake['Lat'],
        text = dfLake['Location'],
        marker = dict(
            size = dfLake['Lunkers per Acre'] *10000,
            color = colors[i],
            line_color='rgb(40,40,40)',
            line_width=0.5,
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1])))
fig.update_layout(
        title_text = 'Texas Lakes by Lunker Density',
        showlegend = True,
        geo = dict(
            scope = 'usa',
            landcolor = 'rgb(217, 217, 217)',
        )
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2d74e85b-4f22-4710-8f84-361c2c5303b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2d74e85b-4f22-4710-8f84-361c2c5303b5")) {
#                     Plotly.newPlot(
#                         '2d74e85b-4f22-4710-8f84-361c2c5303b5',
#                         [{"lat": [32.4353001, "N/A", 31.861188, 32.8171209, 32.23531, 32.8602455, 32.272674, 30.1377119, 31.118922, 32.7237839, "N/A", 33.621481, "N/A", 30.973718, 33.2400059, 30.730455, 30.1179069, "N/A", "N/A", 33.387614, 33.7347947, 33.0874372, "N/A", "N/A", 31.738922, 30.1643501, "N/A", 30.6561268, 29.53786199999999, 32.4903649, 32.993643, "N/A", 32.6440521, 33.0479289, 33.100028, 31.814887, 31.943578, 32.8579361, 31.7124119, "N/A", 32.8815679, "N/A", 32.746336, 33.6813809, 32.3288509, 33.802569, 31.8087129, 32.3328414, "N/A", "N/A", 32.3793427, 33.0059273, 33.5240548, 32.1055466, 30.3678279, 32.3418892, "N/A", 33.190797, 32.9105411, 34.507065, 31.5811736, 31.6599311, 32.494405, 32.817994, 32.2669851, "N/A", 31.969234, 33.013469, 33.0493109, "N/A", 33.1062257, 32.46777170000001, 32.7274971, 30.4199119, 32.9800768, 32.762639, 32.58471, 32.6077651, "N/A", 31.5928861, 32.025497, 31.451699, "N/A", 30.7398537, 32.9596388, "N/A", "N/A", 32.0528791, 31.6734481, 31.7939515, 31.7213059, 32.8106639, 30.6274394, "N/A", 31.9988194, 31.9200098, 32.0102039, 32.4309281, 33.101063, 32.977266, 33.3620647, 30.5168629, 31.1490452, 31.8084129, 30.8595853, 35.028577, 30.742566, 30.7260659, 30.7573852, 30.59232969999999, 30.6276934, 29.8241275, "N/A", 30.628249, 30.3229062, 32.6244809, 33.0645927, "N/A", 33.8342069, 33.19643, 34.0161867, 33.5456201, 32.2836513, 32.40555, 32.4190041, 31.8662569, 32.420774, 32.6505242, 33.824245, 31.9872452, 32.6161006, "N/A", 33.126417, 35.0237935, "N/A", 32.7449841, 33.2507539, 32.6381996, 32.4646399, "N/A", 29.4775189, 31.654093, 30.318747, 34.5527279, 26.3498339, 35.728997, 33.1598299, 31.3920679, 33.1415694, 31.5453158, 31.6173963, 29.4660399, "N/A", 32.779359, 33.0046086, "N/A", 33.0999361, 32.5010369, 31.3979249, "N/A", "N/A", 34.2124969], "locationmode": "USA-states", "lon": [-97.18799, "N/A", -97.214856, -97.037008, -95.7195199, -96.8496799, -96.69007289999999, -97.2775851, -97.42600089999999, -97.411845, "N/A", -96.1380729, "N/A", -96.0799689, -97.71976079999999, -96.245722, -97.4914326, "N/A", "N/A", -95.67388009999999, -95.5665401, -95.1399868, "N/A", "N/A", -96.132352, -96.5698439, "N/A", -96.0275692, -97.41239189999999, -97.68269339999999, -97.015821, "N/A", -96.9765254, -96.378913, -96.86586609999999, -96.23662879999999, -97.629374, -97.3813708, -96.453443, "N/A", -98.01359990000002, "N/A", -96.930234, -97.36259500000001, -96.050951, -97.7072879, -95.589147, -97.41373379999999, "N/A", "N/A", -95.9673967, -96.4577812, -96.8769188, -96.0928251, -96.5090359, -97.7469886, "N/A", -95.55541889999999, -95.99877190000001, -95.75126399999999, -96.9301337, -97.04598, -96.7458521, -97.659919, -97.7646793, "N/A", -97.2964898, -95.149962, -97.033715, "N/A", -95.00143299999999, -94.479976, -98.65703119999999, -95.39037809999999, -95.47805, -94.920492, -94.903348, -95.19031389999999, "N/A", -94.95801700000001, -95.208246, -94.6772033, "N/A", -94.9082964, -94.693884, "N/A", "N/A", -94.4161783, -94.5935004, -94.5721413, -94.3280728, -95.42037409999999, -95.5239699, "N/A", -94.9748789, -94.3774229, -93.5635373, -95.1933069, -94.8218539, -95.26403810000001, -94.1602583, -97.5684199, -99.3756337, -98.941918, -98.3684542, -101.87524, -97.585174, -97.43405690000002, -98.35881069999999, -98.3371481, -98.2366112, -99.22798019999999, "N/A", -97.369248, -97.5858252, -99.62308399999999, -101.0285893, "N/A", -98.95293, -98.376609, -98.73200949999999, -101.6858041, -100.8578467, -98.9560319, -99.4803699, -99.3996619, -100.8358791, -98.8359346, -98.9330933, -100.516453, -99.66126949999999, "N/A", -98.5494569, -100.8943838, "N/A", -99.1155259, -98.110704, -101.1346447, -96.183588, "N/A", -98.37380309999999, -95.6557179, -97.82566190000001, -101.4378042, -98.1953889, -101.5489051, -95.1111311, -100.4756007, -97.19013930000001, -100.4825201, -99.5961138, -98.7042352, "N/A", -98.2898429, -98.38760080000002, "N/A", -99.561094, -100.355625, -100.5186452, "N/A", "N/A", -98.422972], "marker": {"color": "royalblue", "lin ...

# %%
dfLake = dfLake[["Formal Lake Name", "Ratings", "Bass Record", "Lunkers per Acre" , "Lunkers", "Distance","URL" ]].sort_values(by="Distance")

# %%
dfLake[~dfLake.Ratings.isin(["Fair", "Poor"])].sort_values(by="Bass Record", ascending=False)
# Out:
#                    Formal Lake Name  ...                                                                        URL
# 5                         Lake Fork  ...               https://tpwd.texas.gov/fishboat/fish/recreational/lakes/fork
# 21                    Lake Pinkston  ...           https://tpwd.texas.gov/fishboat/fish/recreational/lakes/pinkston
# 24            Sam Rayburn Reservoir  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/sam_rayburn
# 39             Mill Creek Reservoir  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/mill_creek
# 3                        Caddo Lake  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/caddo
# 27          Gibbons Creek Reservoir  ...      https://tpwd.texas.gov/fishboat/fish/recreational/lakes/gibbons_creek
# 0                       Lake Austin  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/austin/
# 39         Possum Kingdom Reservoir  ...     https://tpwd.texas.gov/fishboat/fish/recreational/lakes/possum_kingdom
# 4                       Lake Conroe  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/conroe
# 19                 Nacogdoches Lake  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/nacogdoches
# 27            Toledo Bend Reservoir  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/toledo_bend
# 29                       Lake Welsh  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/welsh
# 10              Houston County Lake  ...     https://tpwd.texas.gov/fishboat/fish/recreational/lakes/houston_county
# 52                 Ray Roberts Lake  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/ray_roberts
# 13                Lake O' the Pines  ...                https://tpwd.texas.gov/fishboat/fish/recreational/lakes/lop
# 11                Lake Jacksonville  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/jacksonville
# 1              Alan Henry Reservoir  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/alan_henry
# 3            Baylor Creek Reservoir  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/baylor
# 18                     Lake Murvaul  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/murvaul
# 8                        Lake Cisco  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/cisco
# 16            Cedar Creek Reservoir  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/cedar_creek
# 37               Marine Creek  Lake  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/marine_creek
# 32                    Joe Pool Lake  ...           https://tpwd.texas.gov/fishboat/fish/recreational/lakes/joe_pool
# 1               Lake Amon G. Carter  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/amon_carter
# 1                  Lake Bob Sandlin  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/bob_sandlin
# 12                      Lake Travis  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/travis/
# 4                       Lake Athens  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/athens
# 20                   Lake Naconiche  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/naconiche
# 51                 Lake Ray Hubbard  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/ray_hubbard
# 17                  Lake Monticello  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/monticello
# 10              Big Creek Reservoir  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/big_creek
# 6                       Lake Gilmer  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/gilmer
# 8                       Belton Lake  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/belton
# 2           Brandy Branch Reservoir  ...      https://tpwd.texas.gov/fishboat/fish/recreational/lakes/brandy_branch
# 61                        Lake Waco  ...               https://tpwd.texas.gov/fishboat/fish/recreational/lakes/waco
# 50     Purtis Creek State Park Lake  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/purtis_creek
# 8            Lake Lyndon B. Johnson  ...               https://tpwd.texas.gov/fishboat/fish/recreational/lakes/lbj/
# 21             Lake Cypress Springs  ...    https://tpwd.texas.gov/fishboat/fish/recreational/lakes/cypress_springs
# 36              Oak Creek Reservoir  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/oak_creek
# 34                  Lake Lewisville  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/lewisville
# 22                     Lake Quitman  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/quitman
# 54                  Lake Somerville  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/somerville
# 2                    Lake Brownwood  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/brownwood/
# 11  Lady Bird  (formerly Town Lake)  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/lady_bird/
# 23                       Lake Raven  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/raven
# 45                      Lake Nocona  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/nocona
# 3                    Lake Arlington  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/arlington
# 44            White River Reservoir  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/white_river
# 41                        Moss Lake  ...               https://tpwd.texas.gov/fishboat/fish/recreational/lakes/moss
# 46                   Lake Palestine  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/palestine
# 9                     Lake Holbrook  ...           https://tpwd.texas.gov/fishboat/fish/recreational/lakes/holbrook
# 60     Tradinghouse Creek Reservoir  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/tradinghouse
# 26                   Leon Reservoir  ...               https://tpwd.texas.gov/fishboat/fish/recreational/lakes/leon
# 56      Stillhouse Hollow Reservoir  ...  https://tpwd.texas.gov/fishboat/fish/recreational/lakes/stillhouse_hollow
# 19            Hords Creek Reservoir  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/hords_creek
# 20          Hubbard Creek Reservoir  ...      https://tpwd.texas.gov/fishboat/fish/recreational/lakes/hubbard_creek
# 10                     Lake Coleman  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/coleman
# 0                Alvarado Park Lake  ...           https://tpwd.texas.gov/fishboat/fish/recreational/lakes/alvarado
# 14                  Lake Bridgeport  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/bridgeport
# 32                   Lake Nasworthy  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/nasworthy
# 22               Davy Crockett Lake  ...      https://tpwd.texas.gov/fishboat/fish/recreational/lakes/davy_crockett
# 16                Martin Creek Lake  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/martin_creek
# 7                         Inks Lake  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/inks/
# 41               Stamford Reservoir  ...           https://tpwd.texas.gov/fishboat/fish/recreational/lakes/stamford
# 12                      Lake Daniel  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/daniel
# 28              Mackenzie Reservoir  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/mackenzie
# 8                      Lake Hawkins  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/hawkins
# 63                 Lake Weatherford  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/weatherford
# 17                      Lake Graham  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/graham
# 18              Greenbelt Reservoir  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/greenbelt
# 62                  Lake Waxahachie  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/waxahachie
# 31               Wright Patman Lake  ...      https://tpwd.texas.gov/fishboat/fish/recreational/lakes/wright_patman
# 25         Fayette County Reservoir  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/fayette
# 13              Walter E. Long Lake  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/walter_long/
# 36         Meridian State Park Lake  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/meridiansp
# 30                   Grapevine Lake  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/grapevine
# 4                       Lake Bryson  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/bryson
# 59                      Lake Texoma  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/texoma
# 29                    Lake Granbury  ...           https://tpwd.texas.gov/fishboat/fish/recreational/lakes/granbury
# 35                   Lake Limestone  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/limestone
# 4                       Canyon Lake  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/canyon/
# 23              Eagle Mountain Lake  ...     https://tpwd.texas.gov/fishboat/fish/recreational/lakes/eagle_mountain
# 66                     Lake Whitney  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/whitney
# 17         Cleburne State Park Lake  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/cleburnesp
# 3                     Lake Buchanan  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/buchanan/
# 11                 Bonham City Lake  ...             https://tpwd.texas.gov/fishboat/fish/recreational/lakes/bonham
# 15                   Lone Star Lake  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/lone_star
# 40               Lake Mineral Wells  ...      https://tpwd.texas.gov/fishboat/fish/recreational/lakes/mineral_wells
# 33                       Lake Lavon  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/lavon
# 64         Wheeler Branch Reservoir  ...     https://tpwd.texas.gov/fishboat/fish/recreational/lakes/wheeler_branch
# 55            Squaw Creek Reservoir  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/squaw_creek/
# 15           Fort Phantom Hill Lake  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/fort_phantom
# 47                Pat Cleburne Lake  ...       https://tpwd.texas.gov/fishboat/fish/recreational/lakes/pat_cleburne
# 30                   Lake Winnsboro  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/winnsboro
# 5                   Lake Georgetown  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/georgetown/
# 6              Buffalo Springs Lake  ...    https://tpwd.texas.gov/fishboat/fish/recreational/lakes/buffalo_springs
# 7                      Lake Bastrop  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/bastrop
# 23                        Lake Kemp  ...               https://tpwd.texas.gov/fishboat/fish/recreational/lakes/kemp
# 67                  Lake Wood (H-5)  ...               https://tpwd.texas.gov/fishboat/fish/recreational/lakes/wood
# 65                  White Rock Lake  ...         https://tpwd.texas.gov/fishboat/fish/recreational/lakes/white_rock
# 21                   Lake Jacksboro  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/jacksboro
# 5                      Bachman Lake  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/bachman
# 16                       Lake Fryer  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/fryer
# 43                    Muenster Lake  ...           https://tpwd.texas.gov/fishboat/fish/recreational/lakes/muenster
# 18                 Coffee Mill Lake  ...        https://tpwd.texas.gov/fishboat/fish/recreational/lakes/coffee_mill
# 26                Timpson Reservoir  ...            https://tpwd.texas.gov/fishboat/fish/recreational/lakes/timpson
# 12                  Kurth Reservoir  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/kurth
# 28              Lake Gonzales (H-4)  ...           https://tpwd.texas.gov/fishboat/fish/recreational/lakes/gonzales
# 28                       Lake Tyler  ...              https://tpwd.texas.gov/fishboat/fish/recreational/lakes/tyler
# 13                        Not Found  ...          https://tpwd.texas.gov/fishboat/fish/recreational/lakes/diversion
#
# [110 rows x 7 columns]
